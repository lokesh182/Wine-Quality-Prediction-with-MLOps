# %%
import os

# %%
# %pwd
# Out:
# 'D:\\ML PROJECTS\\Wine-Quality-Prediction-with-MLOps'

# %%
os.chdir("D:\ML PROJECTS\Wine-Quality-Prediction-with-MLOps")

# %%
import pandas as pd

# %%
data = pd.read_csv("artifacts/data_ingestion/winequality-red.csv")
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
import seaborn as sns
sns.countplot(x='quality',data=data)
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
sns.stripplot(x="quality",y="alcohol",data=data,palette="viridis",hue="quality")
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
sns.stripplot(x="quality",y="density",data=data,palette="viridis",hue="quality")
# Out:
# <Axes: xlabel='quality', ylabel='density'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,5))
sns.heatmap(data.isnull(),yticklabels=False,cbar=True,cmap='mako')
# Out:
# <Axes: >

# %% [markdown]
# ## EDA

# %%
import seaborn as sns

# Set the color palette for the countplot
colors = sns.color_palette("Set2")

# Create the countplot with different bar colors
sns.countplot(x='quality', data=data, palette=colors,hue='quality')

# Display the plot
plt.show()
# Out:
# C:\Users\lokes\AppData\Local\Temp\ipykernel_13660\2135085423.py:7: UserWarning: The palette list has more values (8) than needed (6), which may not be intended.
#   sns.countplot(x='quality', data=data, palette=colors,hue='quality')

# %% [markdown]
# - here we can see that we have average wine simple data
# - Now we going to plot swarmplot to see data distribution

# %%
sns.stripplot(x="quality",y="alcohol",data=data)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
sns.stripplot(x="quality",y="density",data=data)
# Out:
# <Axes: xlabel='quality', ylabel='density'>

# %%
sns.violinplot(x="quality",y="density",data=data)
# Out:
# <Axes: xlabel='quality', ylabel='density'>

# %%
sns.violinplot(x="quality",y="alcohol",data=data)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
fig , ax = plt.subplots(ncols = 6, nrows = 2, figsize = (20,10))
i = 0
ax = ax.flatten()

for col , val in data.items():
    sns.boxplot(y=col,data = data,color='b',ax = ax[i])
    i+=1
plt.tight_layout(pad=0.5,w_pad=0.7,h_pad=5.0)

# %% [markdown]
# - here we can see there are lot of outliers so we should remove them

# %%
df1 = data.copy()
df = data._get_numeric_data()
q1 = data.quantile(0.25)
q3 = data.quantile(0.75)

iqr = q3 - q1

lower_bound = q1 -(1.5 * iqr) 
upper_bound = q3 +(1.5 * iqr)


for col in df.columns:
            for i in range(0,len(df[col])):
                if df[col][i] < lower_bound[col]:            
                    df[col][i] = lower_bound[col]

                if df[col][i] > upper_bound[col]:            
                    df[col][i] = upper_bound[col]    


for col in df.columns:
            df1[col] = df[col]

df1.head()
# Out:
# C:\Users\lokes\AppData\Local\Temp\ipykernel_13660\3196410078.py:18: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df[col][i] = upper_bound[col]
# ...

# %%
#lets see whether our data has outliers or not:

# create box plots
fig, ax = plt.subplots(ncols=6, nrows=2, figsize=(20,10))
index = 0
ax = ax.flatten()

for col, value in df1.items():
    sns.boxplot(y=col, data=df1, color='r', ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %% [markdown]
# # now find corelated variables

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df1.corr(), annot=True, fmt='.2f', linewidths=2)
# Out:
# <Axes: >

# %% [markdown]
# - Alcohol is positively correlated with the quality of the red wine.
# - Alcohol has a weak positive correlation with the pH value.
# - Citric acid and density have a strong positive correlation with fixed acidity.
# - pH has a negative correlation with density, fixed acidity, citric acid, and sulfates.

# %%
# Lets see how alcohol concentration is distributed 
#with respect to the quality of the red wine.
sns.histplot(df1['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
from scipy.stats import skew
skew(df1['alcohol'])
# Out:
# 0.7946828280435413

# %% [markdown]
# - The output verifies that alcohol is positively skewed. That gives deeper insight into the alcohol column.

# %%
#Dist plot of all features:
# create dist plot
fig, ax = plt.subplots(ncols=6, nrows=2, figsize=(20,10))
index = 0
ax = ax.flatten()

for col, value in df1.items():
    sns.histplot(value, color='r', ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.7, h_pad=5.0)

# %% [markdown]
# - The above figures show the distribution of the features. Few of them are normally distributed where other are rightly skewed. The range of each feature is also not huge.

# %%
sns.boxplot(x='quality', y='alcohol', data = df1)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
sns.boxplot(x='quality', y='alcohol', data = df1, showfliers=False)
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# - The higher the alcohol concentration is, the higher the quality of the wine.

# %%
#integer columns
colors = ['#C70039','#25B5CE']
fig=plt.figure(figsize=(20,8), tight_layout=True)
plt.suptitle("Analysing the Numeric variables", size=20, weight='bold')
ax=fig.subplot_mosaic("""AB
                         CC
                         DE""")
sns.kdeplot(df1['density'], ax=ax['A'], color=colors[0], fill=True, linewidth=2)
sns.kdeplot(df1['pH'], ax=ax['B'], color=colors[1],fill=True, linewidth=2)
sns.kdeplot(df1['alcohol'], ax=ax['C'], color=colors[0],fill=True, linewidth=2)
sns.kdeplot(df1['sulphates'], ax=ax['D'], color=colors[1],fill=True, linewidth=2)
sns.kdeplot(df1['chlorides'], ax=ax['E'], color=colors[0],fill=True, linewidth=2)
ax['B'].yaxis.set_visible(False)
ax['E'].yaxis.set_visible(False)
ax['A'].yaxis.label.set_alpha(0.5)
ax['C'].yaxis.label.set_alpha(0.5)
ax['A'].yaxis.label.set_alpha(0.5)
ax['C'].yaxis.label.set_alpha(0.5)
ax['D'].yaxis.label.set_alpha(0.5)
for s in ['left','right','top','bottom']:
    ax['A'].spines[s].set_visible(False)
    ax['B'].spines[s].set_visible(False)
    ax['C'].spines[s].set_visible(False)
    ax['D'].spines[s].set_visible(False)
    ax['E'].spines[s].set_visible(False)

# %% [markdown]
# ### Alcohol versus pH¶

# %%
sns.jointplot(x='alcohol',y='pH',data=df1, kind='reg')

# %% [markdown]
# - This Figure shows that alcohol is weakly positively related to the pH values. Moreover, the regression line is depicted in the figure, illustrating the correlation between them.

# %% [markdown]
# - We can quantify the correlation using Pearson regression from scipy.stats, as shown here:

# %%
from scipy.stats import pearsonr
def get_correlation(column1, column2, df):
    pearson_corr, p_value = pearsonr(df1[column1], df1[column2])
    print("Correlation between {} and {} is {}".format(column1,column2, pearson_corr))
    print("P-value of this correlation is {}".format(p_value))

# %%
get_correlation('alcohol','pH', df1)
# Out:
# Correlation between alcohol and pH is 0.19519615255971767
# P-value of this correlation is 3.402775483823699e-15

# %%
import pandas as pd

# Assuming the target variable is 'quality' in the 'df' dataframe
class_distribution = df1['quality'].value_counts()

print(class_distribution)
# Out:
# quality
# 5.0    681
# 6.0    638
# 7.0    199
# 4.0     53
# 7.5     18
# 3.5     10
# Name: count, dtype: int64

# %%
print(df1['quality'].unique())
        
        #if wine quality is 7 or above then we will consider it as good(1) else bad(0)
df1['good_quality'] = [1 if X >=7 else 0 for X in df1['quality']]
        
print(f"No of good vs bad vine Samples :{df1['good_quality'].value_counts()}")
# Out:
# [5.  6.  7.  4.  7.5 3.5]
# No of good vs bad vine Samples :good_quality
# 0    1382
# 1     217
# Name: count, dtype: int64

# %%
df1['quality'] = df1['quality'].apply(lambda x: 1 if x >= 7 else 0)
sns.countplot(data = df1, x = 'quality')
plt.xticks([0,1], ['bad wine','good wine'])
plt.title("Types of Wine")
plt.show()
# Out:
# [2024-06-02 18:56:07,883]: INFO: category Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.]
# [2024-06-02 18:56:07,900]: INFO: category Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.]

# %% [markdown]
# ### we will pass this clean file for validation

# %%
#Apply SMOTE to balance the data
from imblearn.over_sampling import SMOTE

# %%
#parameter for requires seed
random_value = 1000

# %%
X = df1[['fixed acidity', 'volatile acidity', 'sulphates', 'alcohol', 'density']]
y = df1.quality
oversample = SMOTE()
Over = oversample.fit_resample(X,y)
sns.countplot(x=y_ros)
plt.xticks([0,1], ['bad wine','good wine'])
plt.title("Types of Wine")
plt.show()
# Out:
# [2024-06-02 19:54:49,228]: INFO: category Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.]
# [2024-06-02 19:54:49,247]: INFO: category Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.]

# %%
df1.to_csv('data-cleaned.csv', index=True)

# %%
#entity.py

from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class DataValidationConfig:
    root_dir: Path
    STATUS_FILE: str
    unzip_data_dir: Path
    all_schema: dict

# %%
from WineQPrediction.constants import *
from WineQPrediction.utils.common import read_yaml , create_directories

# %%
#configuration.py in project config folder
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        schema_filepath = SCHEMA_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        
        
        self.config = read_yaml(config_filepath)
        self.schema = read_yaml(schema_filepath)
        self.params = read_yaml(params_filepath)
        
        create_directories([self.config.artifacts_root])
        
    
    
    def get_data_validation_config(self) -> DataValidationConfig:
        config = self.config.data_validation
        schema = self.schema.COLUMNS
        
        create_directories([config.root_dir])
        
        data_validation_config = DataValidationConfig(
            root_dir = config.root_dir,
            STATUS_FILE = config.STATUS_FILE,
            unzip_data_dir = config.unzip_data_dir,
            
            all_schema = schema
        )
        return data_validation_config

# %%
import os 
from WineQPrediction import logger

# %%
class DataValidation:
    def __init__(self, config:  DataValidationConfig):
        self.config = config
        
    def validate_all_columns(self) -> bool:
        try:
            validation_status = None
            
            data = pd.read_csv("data-cleaned.csv")
            all_cols = list(data.columns)
            
            all_schema = self.config.all_schema.keys()
            
            for col in all_cols:
                if col not in all_schema:
                    validation_status = False
                    with open(self.config.STATUS_FILE, "w") as file:
                        file.write(f"validation status: {validation_status}")
                   
                
                else:
                    validation_status = True
                    with open(self.config.STATUS_FILE, "w") as file:
                        file.write(f"validation status: {validation_status}")
                    
            return validation_status
        
        except Exception as e:
            raise e

# %%
try:
    config = ConfigurationManager()
    data_validation_config = config.get_data_validation_config()
    data_validation = DataValidation(config=data_validation_config)
    data_validation.validate_all_columns()
except Exception as e:
    logger.error(e)
    raise e
# Out:
# [2024-06-02 18:48:20,442]: INFO: common yaml file: config\config.yaml loaded successfully]
# [2024-06-02 18:48:20,459]: INFO: common yaml file: Schema.yaml loaded successfully]
# [2024-06-02 18:48:20,468]: INFO: common yaml file: params.yaml loaded successfully]
# [2024-06-02 18:48:20,471]: INFO: common created directory at: artifacts_root]
# [2024-06-02 18:48:20,472]: INFO: common created directory at: artifacts/data_validation]
